# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Import & Clean Data

# %%
raw_df = pd.read_csv("DA_Race_Turnout.csv")

# %%
raw_df
# Out:
#      Unnamed: 0  Unnamed: 0.1     WP  CARVALHO  CHAMPION  HENNING  McAULIFFE  \
# 0             0             0   0101        49        17       68         45
# 1             1             1   0102        46        12       27         18
# 2             2             2   0103        95        53       54         44
# 3             3             3   0104        34        13       21         11
# 4             4             4   0105        40        18       50         23
# ..          ...           ...    ...       ...       ...      ...        ...
# 250         250           250   1819        81       146      142         40
# 251         251           251   1821       169        89       41          8
# 252         252           252   1823        66        56       35         38
# 253         253           253  0502A        36        24       29         24
# 254         254           254   2213        41         8       49         30
#
#      ROLLINS  OTHERS  VOTES_CAST  ...  Other Race Percentage  \
# 0        138       1         318  ...              10.075713
# 1         66       0         169  ...              16.948334
# 2        174       2         422  ...              15.539478
# 3         45       2         126  ...              29.458599
# 4         67       0         198  ...              31.024931
# ..       ...     ...         ...  ...                    ...
# 250      182       2         593  ...               7.671550
# 251      147       3         457  ...               5.804625
# 252       93       0         288  ...              12.384937
# 253       55       2         170  ...                    NaN
# 254       62       0         190  ...                    NaN
#
#      Two or more races Percentage  Hispanic Percentage  White Percentage  \
# 0                        3.494467            29.295282         79.732091
# 1                        4.538870            51.810719         73.394495
# 2                        5.662158            41.333753         62.566845
# 3                        6.581741            63.853503         58.227176
# 4                        5.297784            57.617729         57.444598
# ..                            ...                  ...               ...
# 250                      3.392444            18.003084         40.323824
# 251                      2.925908            11.184521          5.238320
# 252                      2.677824            25.523013         21.338912
# 253                           NaN                  NaN               NaN
# 254                           NaN                  NaN               NaN
#
#      White plurality (Y/N)  Black plurality (Y/N)  Hispanic plurality (Y/N)  \
# 0                        Y                      N                         N
# 1                        Y                      N                         N
# 2                        Y                      N                         N
# 3                        N                      N                         Y
# 4                        N                      N                         Y
# ..                     ...                    ...                       ...
# 250                      N                      Y                         N
# 251                      N                      Y                         N
# 252                      N                      Y                         N
# 253                    NaN                    NaN                       NaN
# 254                    NaN                    NaN                       NaN
#
#      Asian plurality (Y/N)   Turnout  Rollins Percentage
# 0                        N  0.230117           39.093484
# 1                        N  0.173214           34.020619
# 2                        N  0.188002           35.365854
# 3                        N  0.141026           31.468531
# 4                        N  0.171131           29.130435
# ..                     ...       ...                 ...
# 250                      N  0.234989           28.706625
# 251                      N  0.243844           29.108911
# 252                      N  0.231241           27.433628
# 253                    NaN       NaN           27.777778
# 254                    NaN  0.228160           27.927928
#
# [255 rows x 48 columns]

# %% [markdown]
# <h3> Drop columns that are useless/unknown </h3>

# %%
drop_columns = ['Unnamed: 0', 'Unnamed: 0.1'] #unidentified/unknown columns (what it represents)
drop_columns += ['Ward', 'Precinct'] #WP == WARD and Precinct == WP
drop_columns += ['Total.1'] #Total == Total.1; infer that total means the # of people in the precinct

drop_columns.append('TOTAL') #VOTES_CAST == TOTAL; therefore VOTES_CAST --> "TOTAL VOTES CAST"
rename_columns={'VOTE CAST': 'VOTE_CAST', 'BALLOTS CAST': 'BALLOTS_CAST'} #rename for better representation

# %%
def clean_columns(df, drop_columns=[], rename_columns={}):
    new_df = df.drop(drop_columns, axis=1)
    return new_df.rename(columns=rename_columns)

# %%
clean_df = clean_columns(raw_df, drop_columns, rename_columns)

# %%
clean_df.head()
# Out:
#      WP  CARVALHO  CHAMPION  HENNING  McAULIFFE  ROLLINS  OTHERS  VOTES_CAST  \
# 0  0101        49        17       68         45      138       1         318
# 1  0102        46        12       27         18       66       0         169
# 2  0103        95        53       54         44      174       2         422
# 3  0104        34        13       21         11       45       2         126
# 4  0105        40        18       50         23       67       0         198
#
#    BLANKS  BALLOTS_CAST  ...  Other Race Percentage  \
# 0      35           353  ...              10.075713
# 1      25           194  ...              16.948334
# 2      70           492  ...              15.539478
# 3      17           143  ...              29.458599
# 4      32           230  ...              31.024931
#
#    Two or more races Percentage  Hispanic Percentage  White Percentage  \
# 0                      3.494467            29.295282         79.732091
# 1                      4.538870            51.810719         73.394495
# 2                      5.662158            41.333753         62.566845
# 3                      6.581741            63.853503         58.227176
# 4                      5.297784            57.617729         57.444598
#
#    White plurality (Y/N)  Black plurality (Y/N)  Hispanic plurality (Y/N)  \
# 0                      Y                      N                         N
# 1                      Y                      N                         N
# 2                      Y                      N                         N
# 3                      N                      N                         Y
# 4                      N                      N                         Y
#
#    Asian plurality (Y/N)   Turnout  Rollins Percentage
# 0                      N  0.230117           39.093484
# 1                      N  0.173214           34.020619
# 2                      N  0.188002           35.365854
# 3                      N  0.141026           31.468531
# 4                      N  0.171131           29.130435
#
# [5 rows x 42 columns]

# %% [markdown]
# <h3> Focus on
